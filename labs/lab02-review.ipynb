# %% [markdown]
# <a href="https://colab.research.google.com/github/tusharsachdeva-code/comp215/blob/main/labs/lab02-review.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# COMP 215 - LAB 2
# ----------------
# #### Name(s):
# #### Date:
#
# By the end of this lab you should be able to:
#   * use strings, tuples, lists, and dictionaries (review)
#   * use *f-string* to simplify string formatting operations
#   * write functions and simple unit tests (review)
#   * use *list comprehension* to implement map and filter algorithms
#
#
# During this lab, you will be introduced to the following:
#   * API Keys
#   * JSON data formats
#   * the `datetime` module to represent dates and times
#   * the `pprint` module to format data structures

# %% [markdown]
# ## Near Earth Objects
#
# In this lab, we'll answer some questions about [Near Earth Objects](https://cneos.jpl.nasa.gov/) using NASA's API:  [https://api.nasa.gov/](https://api.nasa.gov/#NeoWS).  But, as usual, let's do the imports first.

# %%
import datetime, json, requests
from pprint import pprint    # Pretty Print - built-in python function to nicely format data structures

# %% [markdown]
# ### dates & f-strings
#
# First we need a short tutorial on python dates and [f-strings](https://realpython.com/python-f-strings/)...

# %%
today = datetime.date.today()   # get a date object representing today's date
print(today, type(today))
formatted_date = f'Today is: {today}'   # A format string - notice how the variable `today` is formatted into the string
print(formatted_date)
# Out:
# 2025-01-15 <class 'datetime.date'>
# Today is: 2025-01-15

# %% [markdown]
# ### Make an API Query
#
# Let's get some data from the NEO database; here's a query that gets the observation "feed" for today.  Notice the first line of the block is an 'API key'.  An API key is a unique identifier that authenticates a user when making a request to an API.  Run the block below using the API key 'DEMO_KEY' (just to be sure it works), then go to https://api.nasa.gov and get your own API key.  Use your own API key for the remainder of the lab.

# %%
API_KEY = 'DEMO_KEY'  # substitute your API key here

# get today's date (as a string)
#today = str(datetime.date.today())
today = '2025-01-14'

# use an f-string to "format" the date and API key varaibles.
url = f'https://api.nasa.gov/neo/rest/v1/feed?start_date={today}&end_date={today}&api_key={API_KEY}'

# make the API request (recall from lab 1)
response = requests.request("GET", url, headers={}, data={})

# convert the response to json format (recall from lab 1)
data = json.loads(response.text)

# TIP: print(data) to see the whole data structure returned, here we grab just the list of NEO's:
n_results = data['element_count']
neos = data['near_earth_objects'][today]
print(f'{n_results} Near Earth Objects found for {today}')
pprint(neos[:1])
# Out:
# 15 Near Earth Objects found for 2025-01-14
# [{'absolute_magnitude_h': 20.74,
#   'close_approach_data': [{'close_approach_date': '2025-01-14',
#                            'close_approach_date_full': '2025-Jan-14 22:33',
#                            'epoch_date_close_approach': 1736893980000,
#                            'miss_distance': {'astronomical': '0.1161214726',
#                                              'kilometers': '17371524.962223362',
#                                              'lunar': '45.1712528414',
#                                              'miles': '10794165.0794399156'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '96974.4703454129',
#                                                  'kilometers_per_second': '26.9373528737',
#                                                  'miles_per_hour': '60256.1646432372'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 1386.8357550659,
#                                   'estimated_diameter_min': 620.2118043909},
#                          'kilometers': {'estimated_diameter_max': 0.4227075246,
#                                         'estimated_diameter_min': 0.1890405519},
#                          'meters': {'estimated_diameter_max': 422.7075246174,
#                                     'estimated_diameter_min': 189.0405519291},
#                          'miles': {'estimated_diameter_max': 0.2626581973,
#                                    'estimated_diameter_min': 0.1174643168}},
#   'id': '2506491',
#   'is_potentially_hazardous_asteroid': True,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2506491?api_key=DEMO_KEY'},
#   'name': '506491 (2003 UW29)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2506491',
#   'neo_reference_id': '2506491'}]

# %% [markdown]
# Next we extract just the potentially hazerdous asteroids, using a Comp115-style list accumulator *loop*:

# %%
hazards =  []
for item in neos:
  if item['is_potentially_hazardous_asteroid'] is True:
    hazards.append(item)
print(f'{len(hazards)} potentially hazardous asteroids identified.')
# Out:
# 3 potentially hazardous asteroids identified.

# %% [markdown]
# ### Fetch Complete Data for One Asteroid
#
# Notice that the record for each `neo` is a dictionary with `id` field that uniquely identifies this record in the database.  We can use this `id` to fetch complete orbital and close approach data for the NEO.  For example, this query fetches the complete data set for the first hazardous asteroid...  Notice that the `miss_distance` field contains the distance (in various units) by which the NEO missed an "orbiting body".

# %%
id = hazards[0]['id']
url = f'https://api.nasa.gov/neo/rest/v1/neo/{id}?api_key={API_KEY}'
response = requests.request("GET", url, headers={}, data={})
data = json.loads(response.text)

pprint(data)
# Out:
# {'absolute_magnitude_h': 20.74,
#  'close_approach_data': [{'close_approach_date': '1901-04-18',
#                           'close_approach_date_full': '1901-Apr-18 15:45',
#                           'epoch_date_close_approach': -2168151300000,
#                           'miss_distance': {'astronomical': '0.0421992908',
#                                             'kilometers': '6312924.019190596',
#                                             'lunar': '16.4155241212',
#                                             'miles': '3922669.0889423848'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '130790.3819011481',
#                                                 'kilometers_per_second': '36.3306616392',
#                                                 'miles_per_hour': '81268.0570207439'}},
#                          {'close_approach_date': '1912-07-16',
#                           'close_approach_date_full': '1912-Jul-16 08:40',
#                           'epoch_date_close_approach': -1813332000000,
#                           'miss_distance': {'astronomical': '0.0840600309',
#                                             'kilometers': '12575201.574774183',
#                                             'lunar': '32.6993520201',
#                                             'miles': '7813867.9246944054'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '132362.841601498',
#                                                 'kilometers_per_second': '36.7674560004',
#                                                 'miles_per_hour': '82245.1223273308'}},
#                          {'close_approach_date': '1915-01-10',
#                           'close_approach_date_full': '1915-Jan-10 18:02',
#                           'epoch_date_close_approach': -1734847080000,
#                           'miss_distance': {'astronomical': '0.0673811447',
#                                             'kilometers': '10080075.725281789',
#                                             'lunar': '26.2112652883',
#                                             'miles': '6263468.6147911282'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '109060.9357834447',
#                                                 'kilometers_per_second': '30.2947043843',
#                                                 'miles_per_hour': '67766.2242372187'}},
#                          {'close_approach_date': '1922-10-30',
#                           'close_approach_date_full': '1922-Oct-30 17:14',
#                           'epoch_date_close_approach': -1488609960000,
#                           'miss_distance': {'astronomical': '0.13231225',
#                                             'kilometers': '19793630.7749075',
#                                             'lunar': '51.46946525',
#                                             'miles': '12299191.8424235'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '122362.1538375683',
#                                                 'kilometers_per_second': '33.9894871771',
#                                                 'miles_per_hour': '76031.0838664601'}},
#                          {'close_approach_date': '1924-01-22',
#                           'close_approach_date_full': '1924-Jan-22 20:38',
#                           'epoch_date_close_approach': -1449804120000,
#                           'miss_distance': {'astronomical': '0.0461536168',
#                                             'kilometers': '6904482.766076216',
#                                             'lunar': '17.9537569352',
#                                             'miles': '4290246.6494591408'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '132043.0340420982',
#                                                 'kilometers_per_second': '36.6786205672',
#                                                 'miles_per_hour': '82046.4063468804'}},
#                          {'close_approach_date': '1934-01-03',
#                           'close_approach_date_full': '1934-Jan-03 17:51',
#                           'epoch_date_close_approach': -1135836540000,
#                           'miss_distance': {'astronomical': '0.1984558096',
#                                             'kilometers': '29688566.405285552',
#                                             'lunar': '77.1993099344',
#                                             'miles': '18447619.7367505376'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '128611.9596996662',
#                                                 'kilometers_per_second': '35.725544361',
#                                                 'miles_per_hour': '79914.4701811621'}},
#                          {'close_approach_date': '1935-04-21',
#                           'close_approach_date_full': '1935-Apr-21 20:32',
#                           'epoch_date_close_approach': -1094959680000,
#                           'miss_distance': {'astronomical': '0.0791203898',
#                                             'kilometers': '11836241.787649726',
#                                             'lunar': '30.7778316322',
#                                             'miles': '7354699.6048931788'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '129740.8292788734',
#                                                 'kilometers_per_second': '36.0391192441',
#                                                 'miles_per_hour': '80615.9058371978'}},
#                          {'close_approach_date': '1939-01-16',
#                           'close_approach_date_full': '1939-Jan-16 08:48',
#                           'epoch_date_close_approach': -976979520000,
#                           'miss_distance': {'astronomical': '0.1645184907',
#                                             'kilometers': '24611615.784334809',
#                                             'lunar': '63.9976928823',
#                                             'miles': '15292948.9049220042'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '91524.4296514535',
#                                                 'kilometers_per_second': '25.423452681',
#                                                 'miles_per_hour': '56869.7213020379'}},
#                          {'close_approach_date': '1941-10-24',
#                           'close_approach_date_full': '1941-Oct-24 07:53',
#                           'epoch_date_close_approach': -889546020000,
#                           'miss_distance': {'astronomical': '0.0362848027',
#                                             'kilometers': '5428129.197290249',
#                                             'lunar': '14.1147882503',
#                                             'miles': '3372883.0805294762'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '104226.6730934664',
#                                                 'kilometers_per_second': '28.9518536371',
#                                                 'miles_per_hour': '64762.4014007708'}},
#                          {'close_approach_date': '1941-11-29',
#                           'close_approach_date_full': '1941-Nov-29 15:31',
#                           'epoch_date_close_approach': -886408140000,
#                           'miss_distance': {'astronomical': '0.0448680292',
#                                             'kilometers': '6712161.599417804',
#                                             'lunar': '17.4536633588',
#                                             'miles': '4170743.8179175352'},
#                           'orbiting_body': 'Mars',
#                           'relative_velocity': {'kilometers_per_hour': '73103.2716982428',
#                                                 'kilometers_per_second': '20.3064643606',
#                                                 'miles_per_hour': '45423.5301282776'}},
#                          {'close_approach_date': '1946-10-28',
#                           'close_approach_date_full': '1946-Oct-28 06:59',
#                           'epoch_date_close_approach': -731437260000,
#                           'miss_distance': {'astronomical': '0.055627119',
#                                             'kilometers': '8321698.51663653',
#                                             'lunar': '21.638949291',
#                                             'miles': '5170863.682102914'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '134402.4958983541',
#                                                 'kilometers_per_second': '37.3340266384',
#                                                 'miles_per_hour': '83512.4841875079'}},
#                          {'close_approach_date': '1958-01-09',
#                           'close_approach_date_full': '1958-Jan-09 18:28',
#                           'epoch_date_close_approach': -377933520000,
#                           'miss_distance': {'astronomical': '0.078053179',
#                                             'kilometers': '11676589.32512873',
#                                             'lunar': '30.362686631',
#                                             'miles': '7255496.164807274'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '112063.3368132229',
#                                                 'kilometers_per_second': '31.1287046703',
#                                                 'miles_per_hour': '69631.7994770829'}},
#                          {'close_approach_date': '1958-01-24',
#                           'close_approach_date_full': '1958-Jan-24 09:56',
#                           'epoch_date_close_approach': -376668240000,
#                           'miss_distance': {'astronomical': '0.0818791897',
#                                             'kilometers': '12248952.376445939',
#                                             'lunar': '31.8510047933',
#                                             'miles': '7611146.0731903982'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '131546.9588988528',
#                                                 'kilometers_per_second': '36.5408219163',
#                                                 'miles_per_hour': '81738.1645446788'}},
#                          {'close_approach_date': '1965-10-29',
#                           'close_approach_date_full': '1965-Oct-29 06:55',
#                           'epoch_date_close_approach': -131735100000,
#                           'miss_distance': {'astronomical': '0.0951807699',
#                                             'kilometers': '14238840.442000113',
#                                             'lunar': '37.0253194911',
#                                             'miles': '8847605.1817550394'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '118103.5717171963',
#                                                 'kilometers_per_second': '32.8065476992',
#                                                 'miles_per_hour': '73384.9665483879'}},
#                          {'close_approach_date': '1969-08-01',
#                           'close_approach_date_full': '1969-Aug-01 08:37',
#                           'epoch_date_close_approach': -13188180000,
#                           'miss_distance': {'astronomical': '0.0391535812',
#                                             'kilometers': '5857292.350392044',
#                                             'lunar': '15.2307430868',
#                                             'miles': '3639552.6982324472'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '130175.6236419139',
#                                                 'kilometers_per_second': '36.1598954561',
#                                                 'miles_per_hour': '80886.0701457215'}},
#                          {'close_approach_date': '1980-10-28',
#                           'close_approach_date_full': '1980-Oct-28 22:08',
#                           'epoch_date_close_approach': 341618880000,
#                           'miss_distance': {'astronomical': '0.0869777453',
#                                             'kilometers': '13011685.434282511',
#                                             'lunar': '33.8343429217',
#                                             'miles': '8085086.4184242118'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '133739.4262475599',
#                                                 'kilometers_per_second': '37.1498406243',
#                                                 'miles_per_hour': '83100.4784925463'}},
#                          {'close_approach_date': '1982-01-14',
#                           'close_approach_date_full': '1982-Jan-14 22:04',
#                           'epoch_date_close_approach': 379893840000,
#                           'miss_distance': {'astronomical': '0.1179113471',
#                                             'kilometers': '17639286.374990677',
#                                             'lunar': '45.8675140219',
#                                             'miles': '10960544.3062262626'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '96785.8887745386',
#                                                 'kilometers_per_second': '26.884969104',
#                                                 'miles_per_hour': '60138.9873888237'}},
#                          {'close_approach_date': '1984-10-22',
#                           'close_approach_date_full': '1984-Oct-22 14:19',
#                           'epoch_date_close_approach': 467302740000,
#                           'miss_distance': {'astronomical': '0.087568863',
#                                             'kilometers': '13100115.38312181',
#                                             'lunar': '34.064287707',
#                                             'miles': '8140034.240668578'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '98550.7149777642',
#                                                 'kilometers_per_second': '27.3751986049',
#                                                 'miles_per_hour': '61235.581759378'}},
#                          {'close_approach_date': '1992-05-06',
#                           'close_approach_date_full': '1992-May-06 10:50',
#                           'epoch_date_close_approach': 705149400000,
#                           'miss_distance': {'astronomical': '0.0412508277',
#                                             'kilometers': '6171035.959656999',
#                                             'lunar': '16.0465719753',
#                                             'miles': '3834503.9370206262'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '130930.5274806582',
#                                                 'kilometers_per_second': '36.3695909668',
#                                                 'miles_per_hour': '81355.1380337456'}},
#                          {'close_approach_date': '2001-01-08',
#                           'close_approach_date_full': '2001-Jan-08 11:58',
#                           'epoch_date_close_approach': 978955080000,
#                           'miss_distance': {'astronomical': '0.1009438259',
#                                             'kilometers': '15100981.344290833',
#                                             'lunar': '39.2671482751',
#                                             'miles': '9383314.6972581754'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '115899.1462756231',
#                                                 'kilometers_per_second': '32.1942072988',
#                                                 'miles_per_hour': '72015.2223066504'}},
#                          {'close_approach_date': '2003-08-04',
#                           'close_approach_date_full': '2003-Aug-04 02:45',
#                           'epoch_date_close_approach': 1059965100000,
#                           'miss_distance': {'astronomical': '0.083846108',
#                                             'kilometers': '12543199.16458996',
#                                             'lunar': '32.616136012',
#                                             'miles': '7793982.549103048'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '132551.9006271322',
#                                                 'kilometers_per_second': '36.8199723964',
#                                                 'miles_per_hour': '82362.5962535644'}},
#                          {'close_approach_date': '2003-09-08',
#                           'close_approach_date_full': '2003-Sep-08 09:27',
#                           'epoch_date_close_approach': 1063013220000,
#                           'miss_distance': {'astronomical': '0.0983498728',
#                                             'kilometers': '14712931.485650936',
#                                             'lunar': '38.2581005192',
#                                             'miles': '9142191.6961214768'},
#                           'orbiting_body': 'Merc',
#                           'relative_velocity': {'kilometers_per_hour': '151386.4956268152',
#                                                 'kilometers_per_second': '42.0518043408',
#                                                 'miles_per_hour': '94065.6811298953'}},
#                          {'close_approach_date': '2008-09-28',
#                           'close_approach_date_full': '2008-Sep-28 18:45',
#                           'epoch_date_close_approach': 1222627500000,
#                           'miss_distance': {'astronomical': '0.0976856449',
#                                             'kilometers': '14613564.406616363',
#                                             'lunar': '37.9997158661',
#                                             'miles': '9080447.8563092894'},
#                           'orbiting_body': 'Merc',
#                           'relative_velocity': {'kilometers_per_hour': '151764.6373381933',
#                                                 'kilometers_per_second': '42.1568437051',
#                                                 'miles_per_hour': '94300.6436838346'}},
#                          {'close_approach_date': '2008-10-28',
#                           'close_approach_date_full': '2008-Oct-28 06:17',
#                           'epoch_date_close_approach': 1225174620000,
#                           'miss_distance': {'astronomical': '0.0688943872',
#                                             'kilometers': '10306453.580075264',
#                                             'lunar': '26.7999166208',
#                                             'miles': '6404133.2910520832'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '114991.842941527',
#                                                 'kilometers_per_second': '31.9421785949',
#                                                 'miles_per_hour': '71451.4592988616'}},
#                          {'close_approach_date': '2013-10-20',
#                           'close_approach_date_full': '2013-Oct-20 19:32',
#                           'epoch_date_close_approach': 1382297520000,
#                           'miss_distance': {'astronomical': '0.0814094638',
#                                             'kilometers': '12178682.382322106',
#                                             'lunar': '31.6682814182',
#                                             'miles': '7567482.3235568228'},
#                           'orbiting_body': 'Merc',
#                           'relative_velocity': {'kilometers_per_hour': '160772.5179909986',
#                                                 'kilometers_per_second': '44.6590327753',
#                                                 'miles_per_hour': '99897.790415018'}},
#                          {'close_approach_date': '2015-02-09',
#                           'close_approach_date_full': '2015-Feb-09 20:57',
#                           'epoch_date_close_approach': 1423515420000,
#                           'miss_distance': {'astronomical': '0.049550912',
#                                             'kilometers': '7412710.89175744',
#                                             'lunar': '19.275304768',
#                                             'miles': '4606044.962995072'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '133186.691506252',
#                                                 'kilometers_per_second': '36.9963031962',
#                                                 'miles_per_hour': '82757.0306195375'}},
#                          {'close_approach_date': '2015-04-06',
#                           'close_approach_date_full': '2015-Apr-06 22:45',
#                           'epoch_date_close_approach': 1428360300000,
#                           'miss_distance': {'astronomical': '0.0626457342',
#                                             'kilometers': '9371668.400906154',
#                                             'lunar': '24.3691906038',
#                                             'miles': '5823284.7150227652'},
#                           'orbiting_body': 'Mars',
#                           'relative_velocity': {'kilometers_per_hour': '70682.9418586861',
#                                                 'kilometers_per_second': '19.6341505163',
#                                                 'miles_per_hour': '43919.6312899153'}},
#                          {'close_approach_date': '2018-11-11',
#                           'close_approach_date_full': '2018-Nov-11 16:58',
#                           'epoch_date_close_approach': 1541955480000,
#                           'miss_distance': {'astronomical': '0.0689822422',
#                                             'kilometers': '10319596.500944114',
#                                             'lunar': '26.8340922158',
#                                             'miles': '6412299.9233882132'},
#                           'orbiting_body': 'Merc',
#                           'relative_velocity': {'kilometers_per_hour': '168671.3862767573',
#                                                 'kilometers_per_second': '46.8531628547',
#                                                 'miles_per_hour': '104805.8399895773'}},
#                          {'close_approach_date': '2023-12-03',
#                           'close_approach_date_full': '2023-Dec-03 13:04',
#                           'epoch_date_close_approach': 1701608640000,
#                           'miss_distance': {'astronomical': '0.0595740747',
#                                             'kilometers': '8912154.682340889',
#                                             'lunar': '23.1743150583',
#                                             'miles': '5537756.1304427082'},
#                           'orbiting_body': 'Merc',
#                           'relative_velocity': {'kilometers_per_hour': '176220.0252706136',
#                                                 'kilometers_per_second': '48.9500070196',
#                                                 'miles_per_hour': '109496.2707021766'}},
#                          {'close_approach_date': '2025-01-14',
#                           'close_approach_date_full': '2025-Jan-14 22:33',
#                           'epoch_date_close_approach': 1736893980000,
#                           'miss_distance': {'astronomical': '0.1161214726',
#                                             'kilometers': '17371524.962223362',
#                                             'lunar': '45.1712528414',
#                                             'miles': '10794165.0794399156'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '96974.4703454129',
#                                                 'kilometers_per_second': '26.9373528737',
#                                                 'miles_per_hour': '60256.1646432372'}},
#                          {'close_approach_date': '2026-05-10',
#                           'close_approach_date_full': '2026-May-10 04:34',
#                           'epoch_date_close_approach': 1778387640000,
#                           'miss_distance': {'astronomical': '0.0761187496',
#                                             'kilometers': '11387202.807223352',
#                                             'lunar': '29.6101935944',
#                                             'miles': '7075679.7207801776'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '127149.4232487554',
#                                                 'kilometers_per_second': '35.3192842358',
#                                                 'miles_per_hour': '79005.7069069836'}},
#                          {'close_approach_date': '2027-10-23',
#                           'close_approach_date_full': '2027-Oct-23 15:52',
#                           'epoch_date_close_approach': 1824306720000,
#                           'miss_distance': {'astronomical': '0.0873862512',
#                                             'kilometers': '13072797.046804944',
#                                             'lunar': '33.9932517168',
#                                             'miles': '8123059.4136144672'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '98534.5333045452',
#                                                 'kilometers_per_second': '27.3707036957',
#                                                 'miles_per_hour': '61225.527096927'}},
#                          {'close_approach_date': '2028-12-24',
#                           'close_approach_date_full': '2028-Dec-24 12:04',
#                           'epoch_date_close_approach': 1861272240000,
#                           'miss_distance': {'astronomical': '0.0526212261',
#                                             'kilometers': '7872023.341348407',
#                                             'lunar': '20.4696569529',
#                                             'miles': '4891448.4848337366'},
#                           'orbiting_body': 'Merc',
#                           'relative_velocity': {'kilometers_per_hour': '186263.6455437613',
#                                                 'kilometers_per_second': '51.7399015399',
#                                                 'miles_per_hour': '115736.9857546777'}},
#                          {'close_approach_date': '2034-01-15',
#                           'close_approach_date_full': '2034-Jan-15 12:09',
#                           'epoch_date_close_approach': 2020939740000,
#                           'miss_distance': {'astronomical': '0.0547508731',
#                                             'kilometers': '8190613.996400297',
#                                             'lunar': '21.2980896359',
#                                             'miles': '5089411.5382142186'},
#                           'orbiting_body': 'Merc',
#                           'relative_velocity': {'kilometers_per_hour': '197656.152613987',
#                                                 'kilometers_per_second': '54.9044868372',
#                                                 'miles_per_hour': '122815.8466061743'}},
#                          {'close_approach_date': '2037-11-16',
#                           'close_approach_date_full': '2037-Nov-16 14:01',
#                           'epoch_date_close_approach': 2141992860000,
#                           'miss_distance': {'astronomical': '0.0904724439',
#                                             'kilometers': '13534484.901134493',
#                                             'lunar': '35.1937806771',
#                                             'miles': '8409938.9435142834'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '141645.6509629698',
#                                                 'kilometers_per_second': '39.3460141564',
#                                                 'miles_per_hour': '88013.0990664075'}},
#                          {'close_approach_date': '2039-02-06',
#                           'close_approach_date_full': '2039-Feb-06 10:28',
#                           'epoch_date_close_approach': 2180600880000,
#                           'miss_distance': {'astronomical': '0.064619622',
#                                             'kilometers': '9666957.81140514',
#                                             'lunar': '25.137032958',
#                                             'miles': '6006769.046425332'},
#                           'orbiting_body': 'Merc',
#                           'relative_velocity': {'kilometers_per_hour': '208175.6092929761',
#                                                 'kilometers_per_second': '57.8265581369',
#                                                 'miles_per_hour': '129352.2278965162'}},
#                          {'close_approach_date': '2044-01-10',
#                           'close_approach_date_full': '2044-Jan-10 12:53',
#                           'epoch_date_close_approach': 2336043180000,
#                           'miss_distance': {'astronomical': '0.0836581022',
#                                             'kilometers': '12515073.897362314',
#                                             'lunar': '32.5430017558',
#                                             'miles': '7776506.3184313732'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '113184.2817098212',
#                                                 'kilometers_per_second': '31.4400782527',
#                                                 'miles_per_hour': '70328.3110435275'}},
#                          {'close_approach_date': '2044-02-28',
#                           'close_approach_date_full': '2044-Feb-28 06:54',
#                           'epoch_date_close_approach': 2340255240000,
#                           'miss_distance': {'astronomical': '0.0769711719',
#                                             'kilometers': '11514723.367643853',
#                                             'lunar': '29.9417858691',
#                                             'miles': '7154917.3227290514'},
#                           'orbiting_body': 'Merc',
#                           'relative_velocity': {'kilometers_per_hour': '217481.4444584448',
#                                                 'kilometers_per_second': '60.4115123496',
#                                                 'miles_per_hour': '135134.5119747487'}},
#                          {'close_approach_date': '2049-02-13',
#                           'close_approach_date_full': '2049-Feb-13 14:52',
#                           'epoch_date_close_approach': 2496840720000,
#                           'miss_distance': {'astronomical': '0.0847630406',
#                                             'kilometers': '12680370.328483522',
#                                             'lunar': '32.9728227934',
#                                             'miles': '7879216.7579837236'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '119800.9285608038',
#                                                 'kilometers_per_second': '33.2780357113',
#                                                 'miles_per_hour': '74439.6380826839'}},
#                          {'close_approach_date': '2049-03-20',
#                           'close_approach_date_full': '2049-Mar-20 22:08',
#                           'epoch_date_close_approach': 2499890880000,
#                           'miss_distance': {'astronomical': '0.0849683599',
#                                             'kilometers': '12711085.658433413',
#                                             'lunar': '33.0526920011',
#                                             'miles': '7898302.3790025794'},
#                           'orbiting_body': 'Merc',
#                           'relative_velocity': {'kilometers_per_hour': '222857.6691007746',
#                                                 'kilometers_per_second': '61.9049080835',
#                                                 'miles_per_hour': '138475.0888920896'}},
#                          {'close_approach_date': '2051-10-30',
#                           'close_approach_date_full': '2051-Oct-30 15:36',
#                           'epoch_date_close_approach': 2582292960000,
#                           'miss_distance': {'astronomical': '0.1016520424',
#                                             'kilometers': '15206929.024189688',
#                                             'lunar': '39.5426444936',
#                                             'miles': '9449147.5328381744'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '118726.2852440033',
#                                                 'kilometers_per_second': '32.9795236789',
#                                                 'miles_per_hour': '73771.8965173086'}},
#                          {'close_approach_date': '2056-10-04',
#                           'close_approach_date_full': '2056-Oct-04 14:14',
#                           'epoch_date_close_approach': 2737894440000,
#                           'miss_distance': {'astronomical': '0.0812295743',
#                                             'kilometers': '12151771.296286741',
#                                             'lunar': '31.5983044027',
#                                             'miles': '7550760.5500933858'},
#                           'orbiting_body': 'Merc',
#                           'relative_velocity': {'kilometers_per_hour': '220000.1525676184',
#                                                 'kilometers_per_second': '61.111153491',
#                                                 'miles_per_hour': '136699.5392440293'}},
#                          {'close_approach_date': '2059-05-23',
#                           'close_approach_date_full': '2059-May-23 06:14',
#                           'epoch_date_close_approach': 2820896040000,
#                           'miss_distance': {'astronomical': '0.1142310463',
#                                             'kilometers': '17088721.214351381',
#                                             'lunar': '44.4358770107',
#                                             'miles': '10618438.9790398178'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '108120.5930081128',
#                                                 'kilometers_per_second': '30.0334980578',
#                                                 'miles_per_hour': '67181.9318055132'}},
#                          {'close_approach_date': '2060-08-23',
#                           'close_approach_date_full': '2060-Aug-23 08:43',
#                           'epoch_date_close_approach': 2860476180000,
#                           'miss_distance': {'astronomical': '0.135882728',
#                                             'kilometers': '20327766.67858936',
#                                             'lunar': '52.858381192',
#                                             'miles': '12631088.502718768'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '150335.2267021192',
#                                                 'kilometers_per_second': '41.759785195',
#                                                 'miles_per_hour': '93412.4635027695'}},
#                          {'close_approach_date': '2061-10-26',
#                           'close_approach_date_full': '2061-Oct-26 16:16',
#                           'epoch_date_close_approach': 2897568960000,
#                           'miss_distance': {'astronomical': '0.0635761487',
#                                             'kilometers': '9510856.428323269',
#                                             'lunar': '24.7311218443',
#                                             'miles': '5909772.1447843522'},
#                           'orbiting_body': 'Merc',
#                           'relative_velocity': {'kilometers_per_hour': '206029.848603015',
#                                                 'kilometers_per_second': '57.2305135008',
#                                                 'miles_per_hour': '128018.9356500234'}},
#                          {'close_approach_date': '2066-11-17',
#                           'close_approach_date_full': '2066-Nov-17 11:14',
#                           'epoch_date_close_approach': 3057218040000,
#                           'miss_distance': {'astronomical': '0.0569132474',
#                                             'kilometers': '8514100.585823038',
#                                             'lunar': '22.1392532386',
#                                             'miles': '5290416.7841444044'},
#                           'orbiting_body': 'Merc',
#                           'relative_velocity': {'kilometers_per_hour': '198011.3291793659',
#                                                 'kilometers_per_second': '55.0031469943',
#                                                 'miles_per_hour': '123036.5395114788'}},
#                          {'close_approach_date': '2068-01-17',
#                           'close_approach_date_full': '2068-Jan-17 07:20',
#                           'epoch_date_close_approach': 3094010400000,
#                           'miss_distance': {'astronomical': '0.1545148536',
#                                             'kilometers': '23115092.981921832',
#                                             'lunar': '60.1062780504',
#                                             'miles': '14363052.7553600016'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '92500.2092047882',
#                                                 'kilometers_per_second': '25.6945025569',
#                                                 'miles_per_hour': '57476.0327694974'}},
#                          {'close_approach_date': '2070-10-25',
#                           'close_approach_date_full': '2070-Oct-25 03:20',
#                           'epoch_date_close_approach': 3181432800000,
#                           'miss_distance': {'astronomical': '0.0471132376',
#                                             'kilometers': '7048039.993763912',
#                                             'lunar': '18.3270494264',
#                                             'miles': '4379448.9743775056'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '102953.9352541576',
#                                                 'kilometers_per_second': '28.5983153484',
#                                                 'miles_per_hour': '63971.5716027847'}},
#                          {'close_approach_date': '2071-11-21',
#                           'close_approach_date_full': '2071-Nov-21 07:49',
#                           'epoch_date_close_approach': 3215317740000,
#                           'miss_distance': {'astronomical': '0.1171753165',
#                                             'kilometers': '17529177.764975855',
#                                             'lunar': '45.5811981185',
#                                             'miles': '10892125.988562599'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '110980.6560465127',
#                                                 'kilometers_per_second': '30.8279600129',
#                                                 'miles_per_hour': '68959.0637529012'}},
#                          {'close_approach_date': '2071-12-09',
#                           'close_approach_date_full': '2071-Dec-09 04:56',
#                           'epoch_date_close_approach': 3216862560000,
#                           'miss_distance': {'astronomical': '0.0543930638',
#                                             'kilometers': '8137086.487254106',
#                                             'lunar': '21.1589018182',
#                                             'miles': '5056151.0863384228'},
#                           'orbiting_body': 'Merc',
#                           'relative_velocity': {'kilometers_per_hour': '191157.1249072882',
#                                                 'kilometers_per_second': '53.0992013631',
#                                                 'miles_per_hour': '118777.603529198'}},
#                          {'close_approach_date': '2076-12-29',
#                           'close_approach_date_full': '2076-Dec-29 23:13',
#                           'epoch_date_close_approach': 3376509180000,
#                           'miss_distance': {'astronomical': '0.0553019617',
#                                             'kilometers': '8273055.677141579',
#                                             'lunar': '21.5124631013',
#                                             'miles': '5140638.4232046302'},
#                           'orbiting_body': 'Merc',
#                           'relative_velocity': {'kilometers_per_hour': '184453.0267818182',
#                                                 'kilometers_per_second': '51.2369518838',
#                                                 'miles_per_hour': '114611.9376689581'}},
#                          {'close_approach_date': '2082-01-20',
#                           'close_approach_date_full': '2082-Jan-20 18:19',
#                           'epoch_date_close_approach': 3536158740000,
#                           'miss_distance': {'astronomical': '0.0597844516',
#                                             'kilometers': '8943626.618478092',
#                                             'lunar': '23.2561516724',
#                                             'miles': '5557311.8847459896'},
#                           'orbiting_body': 'Merc',
#                           'relative_velocity': {'kilometers_per_hour': '177479.3133325922',
#                                                 'kilometers_per_second': '49.2998092591',
#                                                 'miles_per_hour': '110278.7433315766'}},
#                          {'close_approach_date': '2082-02-26',
#                           'close_approach_date_full': '2082-Feb-26 07:01',
#                           'epoch_date_close_approach': 3539314860000,
#                           'miss_distance': {'astronomical': '0.0826747442',
#                                             'kilometers': '12367965.635114854',
#                                             'lunar': '32.1604754938',
#                                             'miles': '7685097.4829548252'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '113640.7927542746',
#                                                 'kilometers_per_second': '31.5668868762',
#                                                 'miles_per_hour': '70611.9692533436'}},
#                          {'close_approach_date': '2087-01-11',
#                           'close_approach_date_full': '2087-Jan-11 09:30',
#                           'epoch_date_close_approach': 3693115800000,
#                           'miss_distance': {'astronomical': '0.0714378972',
#                                             'kilometers': '10686957.258398964',
#                                             'lunar': '27.7893420108',
#                                             'miles': '6640567.3131711432'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '110823.814737086',
#                                                 'kilometers_per_second': '30.7843929825',
#                                                 'miles_per_hour': '68861.6086626077'}},
#                          {'close_approach_date': '2087-02-11',
#                           'close_approach_date_full': '2087-Feb-11 03:11',
#                           'epoch_date_close_approach': 3695771460000,
#                           'miss_distance': {'astronomical': '0.0599684348',
#                                             'kilometers': '8971150.113313876',
#                                             'lunar': '23.3277211372',
#                                             'miles': '5574414.1913924488'},
#                           'orbiting_body': 'Merc',
#                           'relative_velocity': {'kilometers_per_hour': '177231.0433613562',
#                                                 'kilometers_per_second': '49.2308453782',
#                                                 'miles_per_hour': '110124.4780263938'}},
#                          {'close_approach_date': '2088-08-14',
#                           'close_approach_date_full': '2088-Aug-14 02:33',
#                           'epoch_date_close_approach': 3743289180000,
#                           'miss_distance': {'astronomical': '0.0491134235',
#                                             'kilometers': '7347263.544007945',
#                                             'lunar': '19.1051217415',
#                                             'miles': '4565377.866861841'},
#                           'orbiting_body': 'Mars',
#                           'relative_velocity': {'kilometers_per_hour': '72774.9656322901',
#                                                 'kilometers_per_second': '20.2152682312',
#                                                 'miles_per_hour': '45219.5335063527'}},
#                          {'close_approach_date': '2092-03-03',
#                           'close_approach_date_full': '2092-Mar-03 03:17',
#                           'epoch_date_close_approach': 3855352620000,
#                           'miss_distance': {'astronomical': '0.0559500807',
#                                             'kilometers': '8370012.899048109',
#                                             'lunar': '21.7645813923',
#                                             'miles': '5200884.8472335442'},
#                           'orbiting_body': 'Merc',
#                           'relative_velocity': {'kilometers_per_hour': '182766.4500017837',
#                                                 'kilometers_per_second': '50.7684583338',
#                                                 'miles_per_hour': '113563.9644469416'}},
#                          {'close_approach_date': '2094-08-25',
#                           'close_approach_date_full': '2094-Aug-25 23:09',
#                           'epoch_date_close_approach': 3933616140000,
#                           'miss_distance': {'astronomical': '0.1100734267',
#                                             'kilometers': '16466750.177921129',
#                                             'lunar': '42.8185629863',
#                                             'miles': '10231964.0980804202'},
#                           'orbiting_body': 'Venus',
# ...
#                                             'kilometers': '16021286.781064986',
#                                             'lunar': '41.6602225542',
#                                             'miles': '9955165.9785733668'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '109294.2182595344',
#                                                 'kilometers_per_second': '30.3595050721',
#                                                 'miles_per_hour': '67911.1768957646'}},
#                          {'close_approach_date': '2151-09-12',
#                           'close_approach_date_full': '2151-Sep-12 05:52',
#                           'epoch_date_close_approach': 5733784320000,
#                           'miss_distance': {'astronomical': '0.1390044428',
#                                             'kilometers': '20794768.563416836',
#                                             'lunar': '54.0727282492',
#                                             'miles': '12921270.0180548968'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '150952.3528429886',
#                                                 'kilometers_per_second': '41.9312091231',
#                                                 'miles_per_hour': '93795.9216873559'}},
#                          {'close_approach_date': '2152-11-13',
#                           'close_approach_date_full': '2152-Nov-13 22:27',
#                           'epoch_date_close_approach': 5770823220000,
#                           'miss_distance': {'astronomical': '0.081830252',
#                                             'kilometers': '12241631.40076324',
#                                             'lunar': '31.831968028',
#                                             'miles': '7606597.029843112'},
#                           'orbiting_body': 'Merc',
#                           'relative_velocity': {'kilometers_per_hour': '160505.1892280714',
#                                                 'kilometers_per_second': '44.5847747856',
#                                                 'miles_per_hour': '99731.6827178536'}},
#                          {'close_approach_date': '2154-01-16',
#                           'close_approach_date_full': '2154-Jan-16 06:47',
#                           'epoch_date_close_approach': 5807832420000,
#                           'miss_distance': {'astronomical': '0.0942350053',
#                                             'kilometers': '14097356.072318711',
#                                             'lunar': '36.6574170617',
#                                             'miles': '8759690.8710757718'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '99687.6752525762',
#                                                 'kilometers_per_second': '27.6910209035',
#                                                 'miles_per_hour': '61942.0446590244'}},
#                          {'close_approach_date': '2156-10-24',
#                           'close_approach_date_full': '2156-Oct-24 00:19',
#                           'epoch_date_close_approach': 5895245940000,
#                           'miss_distance': {'astronomical': '0.1148145982',
#                                             'kilometers': '17176019.335625834',
#                                             'lunar': '44.6628786998',
#                                             'miles': '10672683.5162471492'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '95814.7690588078',
#                                                 'kilometers_per_second': '26.6152136274',
#                                                 'miles_per_hour': '59535.5713632353'}},
#                          {'close_approach_date': '2157-12-05',
#                           'close_approach_date_full': '2157-Dec-05 14:55',
#                           'epoch_date_close_approach': 5930463300000,
#                           'miss_distance': {'astronomical': '0.0889805425',
#                                             'kilometers': '13311299.629444475',
#                                             'lunar': '34.6134310325',
#                                             'miles': '8271258.046404755'},
#                           'orbiting_body': 'Merc',
#                           'relative_velocity': {'kilometers_per_hour': '156389.2480749697',
#                                                 'kilometers_per_second': '43.4414577986',
#                                                 'miles_per_hour': '97174.1969496944'}},
#                          {'close_approach_date': '2161-12-21',
#                           'close_approach_date_full': '2161-Dec-21 11:40',
#                           'epoch_date_close_approach': 6058064400000,
#                           'miss_distance': {'astronomical': '0.0717007784',
#                                             'kilometers': '10726283.725982008',
#                                             'lunar': '27.8916027976',
#                                             'miles': '6665003.6469993904'},
#                           'orbiting_body': 'Mars',
#                           'relative_velocity': {'kilometers_per_hour': '70346.2833488891',
#                                                 'kilometers_per_second': '19.5406342636',
#                                                 'miles_per_hour': '43710.4447842028'}},
#                          {'close_approach_date': '2162-12-09',
#                           'close_approach_date_full': '2162-Dec-09 17:57',
#                           'epoch_date_close_approach': 6088586220000,
#                           'miss_distance': {'astronomical': '0.108525743',
#                                             'kilometers': '16235219.99296741',
#                                             'lunar': '42.216514027',
#                                             'miles': '10088097.912313858'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '112792.2379433766',
#                                                 'kilometers_per_second': '31.3311772065',
#                                                 'miles_per_hour': '70084.7102932053'}},
#                          {'close_approach_date': '2162-12-27',
#                           'close_approach_date_full': '2162-Dec-27 05:14',
#                           'epoch_date_close_approach': 6090095640000,
#                           'miss_distance': {'astronomical': '0.094269423',
#                                             'kilometers': '14102504.88692901',
#                                             'lunar': '36.670805547',
#                                             'miles': '8762890.196119938'},
#                           'orbiting_body': 'Merc',
#                           'relative_velocity': {'kilometers_per_hour': '153572.9288082595',
#                                                 'kilometers_per_second': '42.6591468912',
#                                                 'miles_per_hour': '95424.2456808877'}},
#                          {'close_approach_date': '2173-01-10',
#                           'close_approach_date_full': '2173-Jan-10 03:23',
#                           'epoch_date_close_approach': 6406917780000,
#                           'miss_distance': {'astronomical': '0.1123094782',
#                                             'kilometers': '16801258.719531434',
#                                             'lunar': '43.6883870198',
#                                             'miles': '10439818.0675204292'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '117757.2454614086',
#                                                 'kilometers_per_second': '32.7103459615',
#                                                 'miles_per_hour': '73169.7728812847'}},
#                          {'close_approach_date': '2173-03-16',
#                           'close_approach_date_full': '2173-Mar-16 23:20',
#                           'epoch_date_close_approach': 6412605600000,
#                           'miss_distance': {'astronomical': '0.0851303518',
#                                             'kilometers': '12735319.301630666',
#                                             'lunar': '33.1157068502',
#                                             'miles': '7913360.4666325508'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '113132.9763020228',
#                                                 'kilometers_per_second': '31.4258267506',
#                                                 'miles_per_hour': '70296.4318583319'}},
#                          {'close_approach_date': '2180-10-29',
#                           'close_approach_date_full': '2180-Oct-29 20:23',
#                           'epoch_date_close_approach': 6653132580000,
#                           'miss_distance': {'astronomical': '0.0536435802',
#                                             'kilometers': '8024965.337094174',
#                                             'lunar': '20.8673526978',
#                                             'miles': '4986482.2342166412'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '113058.5163522462',
#                                                 'kilometers_per_second': '31.4051434312',
#                                                 'miles_per_hour': '70250.1653412054'}},
#                          {'close_approach_date': '2185-09-14',
#                           'close_approach_date_full': '2185-Sep-14 11:15',
#                           'epoch_date_close_approach': 6806978100000,
#                           'miss_distance': {'astronomical': '0.1260246414',
#                                             'kilometers': '18853017.920953818',
#                                             'lunar': '49.0235855046',
#                                             'miles': '11714722.1171979684'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '108919.4355781229',
#                                                 'kilometers_per_second': '30.2553987717',
#                                                 'miles_per_hour': '67678.3015124175'}},
#                          {'close_approach_date': '2195-12-22',
#                           'close_approach_date_full': '2195-Dec-22 02:35',
#                           'epoch_date_close_approach': 7131033300000,
#                           'miss_distance': {'astronomical': '0.0532600635',
#                                             'kilometers': '7967592.055664745',
#                                             'lunar': '20.7181647015',
#                                             'miles': '4950832.130253681'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '119098.5483244676',
#                                                 'kilometers_per_second': '33.0829300901',
#                                                 'miles_per_hour': '74003.2063186116'}},
#                          {'close_approach_date': '2197-01-16',
#                           'close_approach_date_full': '2197-Jan-16 22:01',
#                           'epoch_date_close_approach': 7164885660000,
#                           'miss_distance': {'astronomical': '0.1081453112',
#                                             'kilometers': '16178308.206007144',
#                                             'lunar': '42.0685260568',
#                                             'miles': '10052734.5677168272'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '97849.4606274884',
#                                                 'kilometers_per_second': '27.1804057299',
#                                                 'miles_per_hour': '60799.8495771191'}},
#                          {'close_approach_date': '2199-10-25',
#                           'close_approach_date_full': '2199-Oct-25 14:11',
#                           'epoch_date_close_approach': 7252294260000,
#                           'miss_distance': {'astronomical': '0.0980290293',
#                                             'kilometers': '14664933.981447591',
#                                             'lunar': '38.1332923977',
#                                             'miles': '9112367.4299791158'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '97572.624262798',
#                                                 'kilometers_per_second': '27.1035067397',
#                                                 'miles_per_hour': '60627.8342259591'}}],
#  'designation': '506491',
#  'estimated_diameter': {'feet': {'estimated_diameter_max': 1386.8357550659,
#                                  'estimated_diameter_min': 620.2118043909},
#                         'kilometers': {'estimated_diameter_max': 0.4227075246,
#                                        'estimated_diameter_min': 0.1890405519},
#                         'meters': {'estimated_diameter_max': 422.7075246174,
#                                    'estimated_diameter_min': 189.0405519291},
#                         'miles': {'estimated_diameter_max': 0.2626581973,
#                                   'estimated_diameter_min': 0.1174643168}},
#  'id': '2506491',
#  'is_potentially_hazardous_asteroid': True,
#  'is_sentry_object': False,
#  'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2506491?api_key=DEMO_KEY'},
#  'name': '506491 (2003 UW29)',
#  'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2506491',
#  'neo_reference_id': '2506491',
#  'orbital_data': {'aphelion_distance': '2.150376716446403',
#                   'ascending_node_longitude': '196.4797350919183',
#                   'data_arc_in_days': 8777,
#                   'eccentricity': '.8386279599437136',
#                   'epoch_osculation': '2460600.5',
#                   'equinox': 'J2000',
#                   'first_observation_date': '2000-12-29',
#                   'inclination': '3.756551771009501',
#                   'jupiter_tisserand_invariant': '4.964',
#                   'last_observation_date': '2025-01-09',
#                   'mean_anomaly': '255.9570867426442',
#                   'mean_motion': '.7792432349034304',
#                   'minimum_orbit_intersection': '.0180847',
#                   'observations_used': 135,
#                   'orbit_class': {'orbit_class_description': 'Near-Earth '
#                                                              'asteroid orbits '
#                                                              'which cross the '
#                                                              'Earth’s orbit '
#                                                              'similar to that '
#                                                              'of 1862 Apollo',
#                                   'orbit_class_range': 'a (semi-major axis) > '
#                                                        '1.0 AU; q (perihelion) '
#                                                        '< 1.017 AU',
#                                   'orbit_class_type': 'APO'},
#                   'orbit_determination_date': '2025-01-11 06:22:34',
#                   'orbit_id': '36',
#                   'orbit_uncertainty': '0',
#                   'orbital_period': '461.9866864094288',
#                   'perihelion_argument': '55.26651165763178',
#                   'perihelion_distance': '.188733493225632',
#                   'perihelion_time': '2460734.017890944860',
#                   'semi_major_axis': '1.169555104836017'}}

# %% [markdown]
# ## Exercise 1
#
# In the code cell below, **re-write the accumulator loop** that creates the list of hazards as a [list comprehension](https://realpython.com/lessons/list-comprehensions-overview/) that implements a ["filter"](https://youtu.be/hUes6y2b--0)
# Notice how this provides a concise way to "filter" items of interest from a larger data set.

# %%
# Ex. 1 your code here

hazards = [item for item in neos if item['is_potentially_hazardous_asteroid'] is True]
print(f'{len(hazards)} potentially hazardous asteroids identified.')
# Out:
# 3 potentially hazardous asteroids identified.

# %% [markdown]
# ## Exercise 2
#
# In the code cell below, write a python function that takes a list of "close approach data" as a parameter,
# and returns a 2-tuple with the (date, miss km) of the closest approach to Earth in the list (where "miss km" is the miss distance in km).
#
# Hints:
# * notice the input is a list of dictionaries.  Each dictionary has a 'close_approach_date", "orbiting_body", and 'miss_distance' field.
# * we are only interested in the closest approach to "Earth"
#
#
# Add at least one unit test to check your work - note the test data only needs dictionaries with the fields your function actually uses.

# %%
# Ex. 2 your code here
hazards = [item for item in neos if item['is_potentially_hazardous_asteroid'] is True]

# %% [markdown]
# ## Challenge Exercise
#
# In the code cell below, write a complete program that:
#  1. fetches the list of NEO's for this week.
#  2. for each NEO, fetch it's complete orbital data and determine its closest approach to Earth
#  3. identify which NEO from this week's data makes the closet approach to earth
#  4. print a nice message with information about the NEO, which it will approach the Earth, and how close it will come.
#
# Hints:
# * you'll need the start and end date - end date is today, see if you can use a [`timedelta`](https://docs.python.org/3/library/datetime.html#timedelta-objects) object to ge the start date (you can do basic "date math" with `timedelta` and `date` objects!)
# * you may need to modify the function we wrote in Ex. 2 to return a triple with the NEO's id included;
# * lots of opportunity here for more practice with list comprehensions

# %%
# Ex. 3 (challenge) your code here
