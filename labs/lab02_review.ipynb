# %% [markdown]
# <a href="https://colab.research.google.com/github/Hamilton-at-CapU/comp215/blob/main/labs/lab02_review.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# COMP 215 - LAB 2
# ----------------
# #### Nam(s):
# #### Date:
#
# By the end of this lab you should be able to:
#   * use strings, tuples, lists, and dictionaries (review)
#   * use *f-string* to simplify string formatting operations
#   * write functions and simple unit tests (review)
#   * use *list comprehension* to implement map and filter algorithms
#
#
# During this lab, you will be introduced to the following:
#   * API Keys
#   * JSON data formats
#   * the `datetime` module to represent dates and times
#   * the `pprint` module to format data structures

# %% [markdown]
# ## Near Earth Objects
#
# In this lab, we'll answer some questions about [Near Earth Objects](https://cneos.jpl.nasa.gov/) using NASA's API:  [https://api.nasa.gov/](https://api.nasa.gov/#NeoWS).  But, as usual, let's do the imports first.

# %%
import datetime, json, requests
from pprint import pprint    # Pretty Print - built-in python function to nicely format data structures

# %% [markdown]
# ### dates & f-strings
#
# First we need a short tutorial on python dates and [f-strings](https://realpython.com/python-f-strings/)...

# %%
today = datetime.date.today()   # get a date object representing today's date
print(today, type(today))
formatted_date = f'Today is: {today}'   # A format string - notice how the variable `today` is formatted into the string
print(formatted_date)
# Out:
# 2024-12-27 <class 'datetime.date'>
# Today is: 2024-12-27

# %% [markdown]
# ### Make an API Query
#
# Let's get some data from the NEO database; here's a query that gets the observation "feed" for today.  Notice the first line of the block is an 'API key'.  An API key is a unique identifier that authenticates a user when making a request to an API.  Run the block below using the API key 'DEMO_KEY' (just to be sure it works), then go to https://api.nasa.gov and get your own API key.  Use your own API key for the remainder of the lab.

# %%
API_KEY = 'DEMO_KEY'  # substitute your API key here

# get today's date (as a string)
#today = str(datetime.date.today())
today = '2023-01-09'

# use an f-string to "format" the date and API key varaibles.
url = f'https://api.nasa.gov/neo/rest/v1/feed?start_date={today}&end_date={today}&api_key={API_KEY}'

# make the API request (recall from lab 1)
response = requests.request("GET", url, headers={}, data={})

# convert the response to json format (recall from lab 1)
data = json.loads(response.text)

# TIP: print(data) to see the whole data structure returned, here we grab just the list of NEO's:
n_results = data['element_count']
neos = data['near_earth_objects'][today]
print(f'{n_results} Near Earth Objects found for {today}')
pprint(neos[:1])
# Out:
# 14 Near Earth Objects found for 2023-01-09
# [{'absolute_magnitude_h': 19.62,
#   'close_approach_data': [{'close_approach_date': '2023-01-09',
#                            'close_approach_date_full': '2023-Jan-09 13:59',
#                            'epoch_date_close_approach': 1673272740000,
#                            'miss_distance': {'astronomical': '0.0725378623',
#                                              'kilometers': '10851509.694433301',
#                                              'lunar': '28.2172284347',
#                                              'miles': '6742815.4556135138'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '32387.3479203461',
#                                                  'kilometers_per_second': '8.9964855334',
#                                                  'miles_per_hour': '20124.2384897284'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 2322.8706681664,
#                                   'estimated_diameter_min': 1038.8193433921},
#                          'kilometers': {'estimated_diameter_max': 0.708010957,
#                                         'estimated_diameter_min': 0.3166321257},
#                          'meters': {'estimated_diameter_max': 708.0109570008,
#                                     'estimated_diameter_min': 316.6321257337},
#                          'miles': {'estimated_diameter_max': 0.4399374764,
#                                    'estimated_diameter_min': 0.1967460206}},
#   'id': '2226554',
#   'is_potentially_hazardous_asteroid': True,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2226554?api_key=DEMO_KEY'},
#   'name': '226554 (2003 WR21)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2226554',
#   'neo_reference_id': '2226554'}]

# %% [markdown]
# Next we extract just the potentially hazerdous asteroids, using a Comp115-style list accumulator *loop*:

# %%
hazards =  []
for item in neos:
  if item['is_potentially_hazardous_asteroid'] is True:
    hazards.append(item)
print(f'{len(hazards)} potentially hazardous asteroids identified.')
# Out:
# 3 potentially hazardous asteroids identified.

# %% [markdown]
# ### Fetch Complete Data for One Asteroid
#
# Notice that the record for each `neo` is a dictionary with `id` field that uniquely identifies this record in the database.  We can use this `id` to fetch complete orbital and close approach data for the NEO.  For example, this query fetches the complete data set for the first hazardous asteroid...  Notice that the `miss_distance` field contains the distance (in various units) by which the NEO missed an "orbiting body".

# %%
id = hazards[0]['id']
url = f'https://api.nasa.gov/neo/rest/v1/neo/{id}?api_key={API_KEY}'
response = requests.request("GET", url, headers={}, data={})
data = json.loads(response.text)

pprint(data)
# Out:
# {'absolute_magnitude_h': 19.62,
#  'close_approach_data': [{'close_approach_date': '1900-10-30',
#                           'close_approach_date_full': '1900-Oct-30 21:15',
#                           'epoch_date_close_approach': -2182819500000,
#                           'miss_distance': {'astronomical': '0.4183488933',
#                                             'kilometers': '62584103.354537271',
#                                             'lunar': '162.7377194937',
#                                             'miles': '38887958.5659094998'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30027.9671888418',
#                                                 'kilometers_per_second': '8.3411019969',
#                                                 'miles_per_hour': '18658.2110568667'}},
#                          {'close_approach_date': '1901-06-26',
#                           'close_approach_date_full': '1901-Jun-26 20:27',
#                           'epoch_date_close_approach': -2162172780000,
#                           'miss_distance': {'astronomical': '0.0308794402',
#                                             'kilometers': '4619498.480712374',
#                                             'lunar': '12.0121022378',
#                                             'miles': '2870423.2526198012'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '33428.9789814113',
#                                                 'kilometers_per_second': '9.2858274948',
#                                                 'miles_per_hour': '20771.4675231997'}},
#                          {'close_approach_date': '1907-01-08',
#                           'close_approach_date_full': '1907-Jan-08 04:37',
#                           'epoch_date_close_approach': -1987528980000,
#                           'miss_distance': {'astronomical': '0.124028823',
#                                             'kilometers': '18554447.73940701',
#                                             'lunar': '48.247212147',
#                                             'miles': '11529199.209196338'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '24041.8328517503',
#                                                 'kilometers_per_second': '6.6782869033',
#                                                 'miles_per_hour': '14938.6599739112'}},
#                          {'close_approach_date': '1907-09-06',
#                           'close_approach_date_full': '1907-Sep-06 10:51',
#                           'epoch_date_close_approach': -1966684140000,
#                           'miss_distance': {'astronomical': '0.4147265915',
#                                             'kilometers': '62042214.720760105',
#                                             'lunar': '161.3286440935',
#                                             'miles': '38551244.582515249'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '26520.1865961954',
#                                                 'kilometers_per_second': '7.3667184989',
#                                                 'miles_per_hour': '16478.612610286'}},
#                          {'close_approach_date': '1909-08-06',
#                           'close_approach_date_full': '1909-Aug-06 06:41',
#                           'epoch_date_close_approach': -1906219140000,
#                           'miss_distance': {'astronomical': '0.1317216016',
#                                             'kilometers': '19705271.032348592',
#                                             'lunar': '51.2397030224',
#                                             'miles': '12244287.6443388896'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '7812.3466230468',
#                                                 'kilometers_per_second': '2.1700962842',
#                                                 'miles_per_hour': '4854.2883780815'}},
#                          {'close_approach_date': '1912-12-22',
#                           'close_approach_date_full': '1912-Dec-22 20:02',
#                           'epoch_date_close_approach': -1799553480000,
#                           'miss_distance': {'astronomical': '0.4621482336',
#                                             'kilometers': '69136391.370822432',
#                                             'lunar': '179.7756628704',
#                                             'miles': '42959361.5457642816'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '78889.7388498786',
#                                                 'kilometers_per_second': '21.9138163472',
#                                                 'miles_per_hour': '49019.015787026'}},
#                          {'close_approach_date': '1913-10-29',
#                           'close_approach_date_full': '1913-Oct-29 19:08',
#                           'epoch_date_close_approach': -1772686320000,
#                           'miss_distance': {'astronomical': '0.4230481677',
#                                             'kilometers': '63287104.795322799',
#                                             'lunar': '164.5657372353',
#                                             'miles': '39324783.4053766662'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30216.2149123593',
#                                                 'kilometers_per_second': '8.3933930312',
#                                                 'miles_per_hour': '18775.1808715157'}},
#                          {'close_approach_date': '1914-06-28',
#                           'close_approach_date_full': '1914-Jun-28 14:48',
#                           'epoch_date_close_approach': -1751793120000,
#                           'miss_distance': {'astronomical': '0.0438448039',
#                                             'kilometers': '6559089.274007693',
#                                             'lunar': '17.0556287171',
#                                             'miles': '4075629.0854364434'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '35203.2780209607',
#                                                 'kilometers_per_second': '9.7786883392',
#                                                 'miles_per_hour': '21873.9479458575'}},
#                          {'close_approach_date': '1919-12-30',
#                           'close_approach_date_full': '1919-Dec-30 11:26',
#                           'epoch_date_close_approach': -1578054840000,
#                           'miss_distance': {'astronomical': '0.1880360196',
#                                             'kilometers': '28129788.015438252',
#                                             'lunar': '73.1460116244',
#                                             'miles': '17479039.7589497976'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '22319.5160919295',
#                                                 'kilometers_per_second': '6.1998655811',
#                                                 'miles_per_hour': '13868.4793183436'}},
#                          {'close_approach_date': '1920-02-20',
#                           'close_approach_date_full': '1920-Feb-20 02:19',
#                           'epoch_date_close_approach': -1573594860000,
#                           'miss_distance': {'astronomical': '0.2017013202',
#                                             'kilometers': '30174087.878107974',
#                                             'lunar': '78.4618135578',
#                                             'miles': '18749308.7904550812'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '18957.0219550665',
#                                                 'kilometers_per_second': '5.265839432',
#                                                 'miles_per_hour': '11779.1562253579'}},
#                          {'close_approach_date': '1920-08-27',
#                           'close_approach_date_full': '1920-Aug-27 00:15',
#                           'epoch_date_close_approach': -1557272700000,
#                           'miss_distance': {'astronomical': '0.3922373044',
#                                             'kilometers': '58677865.272781628',
#                                             'lunar': '152.5803114116',
#                                             'miles': '36460734.7737693464'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '24779.5288853952',
#                                                 'kilometers_per_second': '6.8832024682',
#                                                 'miles_per_hour': '15397.035601039'}},
#                          {'close_approach_date': '1924-12-19',
#                           'close_approach_date_full': '1924-Dec-19 14:32',
#                           'epoch_date_close_approach': -1421141280000,
#                           'miss_distance': {'astronomical': '0.1361653344',
#                                             'kilometers': '20370043.994077728',
#                                             'lunar': '52.9683150816',
#                                             'miles': '12657358.4084115264'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '7522.0497886766',
#                                                 'kilometers_per_second': '2.0894582746',
#                                                 'miles_per_hour': '4673.9092145252'}},
#                          {'close_approach_date': '1925-12-28',
#                           'close_approach_date_full': '1925-Dec-28 17:32',
#                           'epoch_date_close_approach': -1388816880000,
#                           'miss_distance': {'astronomical': '0.3364529381',
#                                             'kilometers': '50332642.895001847',
#                                             'lunar': '130.8801929209',
#                                             'miles': '31275254.0421536086'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '65215.0517359122',
#                                                 'kilometers_per_second': '18.1152921489',
#                                                 'miles_per_hour': '40522.097007795'}},
#                          {'close_approach_date': '1926-10-17',
#                           'close_approach_date_full': '1926-Oct-17 17:33',
#                           'epoch_date_close_approach': -1363501620000,
#                           'miss_distance': {'astronomical': '0.4449030569',
#                                             'kilometers': '66556549.668728803',
#                                             'lunar': '173.0672891341',
#                                             'miles': '41356322.2460033614'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30428.2175547942',
#                                                 'kilometers_per_second': '8.4522826541',
#                                                 'miles_per_hour': '18906.9110689775'}},
#                          {'close_approach_date': '1927-07-07',
#                           'close_approach_date_full': '1927-Jul-07 13:11',
#                           'epoch_date_close_approach': -1340794140000,
#                           'miss_distance': {'astronomical': '0.1747005339',
#                                             'kilometers': '26134827.759302793',
#                                             'lunar': '67.9585076871',
#                                             'miles': '16239428.9373048234'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '48367.8376159104',
#                                                 'kilometers_per_second': '13.4355104489',
#                                                 'miles_per_hour': '30053.8933230639'}},
#                          {'close_approach_date': '1932-12-06',
#                           'close_approach_date_full': '1932-Dec-06 07:37',
#                           'epoch_date_close_approach': -1169828580000,
#                           'miss_distance': {'astronomical': '0.2949642119',
#                                             'kilometers': '44126017.826468653',
#                                             'lunar': '114.7410784291',
#                                             'miles': '27418636.0583192914'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '25802.0376608777',
#                                                 'kilometers_per_second': '7.1672326836',
#                                                 'miles_per_hour': '16032.3827898937'}},
#                          {'close_approach_date': '1933-04-15',
#                           'close_approach_date_full': '1933-Apr-15 01:33',
#                           'epoch_date_close_approach': -1158618420000,
#                           'miss_distance': {'astronomical': '0.2180156964',
#                                             'kilometers': '32614683.808006668',
#                                             'lunar': '84.8081058996',
#                                             'miles': '20265824.7795132984'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '26552.346038622',
#                                                 'kilometers_per_second': '7.3756516774',
#                                                 'miles_per_hour': '16498.5952371649'}},
#                          {'close_approach_date': '1933-07-30',
#                           'close_approach_date_full': '1933-Jul-30 19:05',
#                           'epoch_date_close_approach': -1149396900000,
#                           'miss_distance': {'astronomical': '0.317837267',
#                                             'kilometers': '47547778.14982129',
#                                             'lunar': '123.638696863',
#                                             'miles': '29544819.330822202'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '19585.7472813666',
#                                                 'kilometers_per_second': '5.4404853559',
#                                                 'miles_per_hour': '12169.8216926914'}},
#                          {'close_approach_date': '1939-01-04',
#                           'close_approach_date_full': '1939-Jan-04 13:15',
#                           'epoch_date_close_approach': -978000300000,
#                           'miss_distance': {'astronomical': '0.1772516635',
#                                             'kilometers': '26516471.313556745',
#                                             'lunar': '68.9508971015',
#                                             'miles': '16476571.245483281'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '47802.3864073193',
#                                                 'kilometers_per_second': '13.2784406687',
#                                                 'miles_per_hour': '29702.5439318146'}},
#                          {'close_approach_date': '1939-10-02',
#                           'close_approach_date_full': '1939-Oct-02 23:40',
#                           'epoch_date_close_approach': -954548400000,
#                           'miss_distance': {'astronomical': '0.4508022741',
#                                             'kilometers': '67439059.996516167',
#                                             'lunar': '175.3620846249',
#                                             'miles': '41904688.7355984246'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '29767.95850699',
#                                                 'kilometers_per_second': '8.2688773631',
#                                                 'miles_per_hour': '18496.6517734127'}},
#                          {'close_approach_date': '1940-07-15',
#                           'close_approach_date_full': '1940-Jul-15 08:32',
#                           'epoch_date_close_approach': -929806080000,
#                           'miss_distance': {'astronomical': '0.3345358033',
#                                             'kilometers': '50045843.612418971',
#                                             'lunar': '130.1344274837',
#                                             'miles': '31097045.2316089598'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '64571.7208638784',
#                                                 'kilometers_per_second': '17.9365891289',
#                                                 'miles_per_hour': '40122.356222336'}},
#                          {'close_approach_date': '1945-11-18',
#                           'close_approach_date_full': '1945-Nov-18 06:11',
#                           'epoch_date_close_approach': -761161740000,
#                           'miss_distance': {'astronomical': '0.3687537201',
#                                             'kilometers': '55164771.081536187',
#                                             'lunar': '143.4451971189',
#                                             'miles': '34277799.2673939006'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '28578.7414644838',
#                                                 'kilometers_per_second': '7.9385392957',
#                                                 'miles_per_hour': '17757.7185505288'}},
#                          {'close_approach_date': '1946-05-31',
#                           'close_approach_date_full': '1946-May-31 01:46',
#                           'epoch_date_close_approach': -744416040000,
#                           'miss_distance': {'astronomical': '0.1446798965',
#                                             'kilometers': '21643804.348220455',
#                                             'lunar': '56.2804797385',
#                                             'miles': '13448836.391154079'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '24131.1417743834',
#                                                 'kilometers_per_second': '6.7030949373',
#                                                 'miles_per_hour': '14994.1530653106'}},
#                          {'close_approach_date': '1952-01-09',
#                           'close_approach_date_full': '1952-Jan-09 10:55',
#                           'epoch_date_close_approach': -567349500000,
#                           'miss_distance': {'astronomical': '0.073295818',
#                                             'kilometers': '10964898.25270766',
#                                             'lunar': '28.512073202',
#                                             'miles': '6813271.838619308'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '33228.5225541053',
#                                                 'kilometers_per_second': '9.2301451539',
#                                                 'miles_per_hour': '20646.9116947995'}},
#                          {'close_approach_date': '1952-09-18',
#                           'close_approach_date_full': '1952-Sep-18 12:09',
#                           'epoch_date_close_approach': -545485860000,
#                           'miss_distance': {'astronomical': '0.4381149253',
#                                             'kilometers': '65541059.640089111',
#                                             'lunar': '170.4267059417',
#                                             'miles': '40725326.0018912918'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '28395.26875344',
#                                                 'kilometers_per_second': '7.8875746537',
#                                                 'miles_per_hour': '17643.7157429361'}},
#                          {'close_approach_date': '1953-07-22',
#                           'close_approach_date_full': '1953-Jul-22 08:42',
#                           'epoch_date_close_approach': -518973480000,
#                           'miss_distance': {'astronomical': '0.4679450136',
#                                             'kilometers': '70003577.311681032',
#                                             'lunar': '182.0306102904',
#                                             'miles': '43498205.9028689616'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '78393.2306473634',
#                                                 'kilometers_per_second': '21.775897402',
#                                                 'miles_per_hour': '48710.5048986354'}},
#                          {'close_approach_date': '1958-11-06',
#                           'close_approach_date_full': '1958-Nov-06 23:00',
#                           'epoch_date_close_approach': -351910800000,
#                           'miss_distance': {'astronomical': '0.405216778',
#                                             'kilometers': '60619566.87706286',
#                                             'lunar': '157.629326642',
#                                             'miles': '37667252.203713068'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '29821.896055332',
#                                                 'kilometers_per_second': '8.2838600154',
#                                                 'miles_per_hour': '18530.1664683811'}},
#                          {'close_approach_date': '1959-06-22',
#                           'close_approach_date_full': '1959-Jun-22 11:57',
#                           'epoch_date_close_approach': -332251380000,
#                           'miss_distance': {'astronomical': '0.0488501054',
#                                             'kilometers': '7307871.717115498',
#                                             'lunar': '19.0026910006',
#                                             'miles': '4540900.9206419524'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '28870.8549292333',
#                                                 'kilometers_per_second': '8.0196819248',
#                                                 'miles_per_hour': '17939.2264975561'}},
#                          {'close_approach_date': '1965-01-09',
#                           'close_approach_date_full': '1965-Jan-09 06:20',
#                           'epoch_date_close_approach': -157052400000,
#                           'miss_distance': {'astronomical': '0.09189492',
#                                             'kilometers': '13747284.2958204',
#                                             'lunar': '35.74712388',
#                                             'miles': '8542166.35590552'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '27010.412163149',
#                                                 'kilometers_per_second': '7.5028922675',
#                                                 'miles_per_hour': '16783.2197132634'}},
#                          {'close_approach_date': '1965-09-11',
#                           'close_approach_date_full': '1965-Sep-11 11:07',
#                           'epoch_date_close_approach': -135867180000,
#                           'miss_distance': {'astronomical': '0.4256120505',
#                                             'kilometers': '63670656.201132435',
#                                             'lunar': '165.5630876445',
#                                             'miles': '39563111.197540203'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '27282.9103324999',
#                                                 'kilometers_per_second': '7.5785862035',
#                                                 'miles_per_hour': '16952.5394785469'}},
#                          {'close_approach_date': '1970-12-22',
#                           'close_approach_date_full': '1970-Dec-22 03:21',
#                           'epoch_date_close_approach': 30684060000,
#                           'miss_distance': {'astronomical': '0.4970937369',
#                                             'kilometers': '74364164.230580403',
#                                             'lunar': '193.3694636541',
#                                             'miles': '46207748.9710914414'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '82786.0535514853',
#                                                 'kilometers_per_second': '22.9961259865',
#                                                 'miles_per_hour': '51440.0342192549'}},
#                          {'close_approach_date': '1971-11-02',
#                           'close_approach_date_full': '1971-Nov-02 20:26',
#                           'epoch_date_close_approach': 57961560000,
#                           'miss_distance': {'astronomical': '0.4161215604',
#                                             'kilometers': '62250899.096916348',
#                                             'lunar': '161.8712869956',
#                                             'miles': '38680915.0409596824'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30031.6674187783',
#                                                 'kilometers_per_second': '8.3421298385',
#                                                 'miles_per_hour': '18660.5102358515'}},
#                          {'close_approach_date': '1972-06-25',
#                           'close_approach_date_full': '1972-Jun-25 18:40',
#                           'epoch_date_close_approach': 78345600000,
#                           'miss_distance': {'astronomical': '0.0287693216',
#                                             'kilometers': '4303829.232704992',
#                                             'lunar': '11.1912661024',
#                                             'miles': '2674275.4774012096'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '32284.7009474174',
#                                                 'kilometers_per_second': '8.9679724854',
#                                                 'miles_per_hour': '20060.4576525772'}},
#                          {'close_approach_date': '1978-01-06',
#                           'close_approach_date_full': '1978-Jan-06 06:31',
#                           'epoch_date_close_approach': 252916260000,
#                           'miss_distance': {'astronomical': '0.1452315766',
#                                             'kilometers': '21726334.516101842',
#                                             'lunar': '56.4950832974',
#                                             'miles': '13500118.2595037396'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '22857.4910570846',
#                                                 'kilometers_per_second': '6.3493030714',
#                                                 'miles_per_hour': '14202.7560404424'}},
#                          {'close_approach_date': '1978-09-03',
#                           'close_approach_date_full': '1978-Sep-03 16:17',
#                           'epoch_date_close_approach': 273687420000,
#                           'miss_distance': {'astronomical': '0.4089770823',
#                                             'kilometers': '61182100.390894701',
#                                             'lunar': '159.0920850147',
#                                             'miles': '38016794.3207248338'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '26109.7386823731',
#                                                 'kilometers_per_second': '7.2527051895',
#                                                 'miles_per_hour': '16223.5762385001'}},
#                          {'close_approach_date': '1983-12-26',
#                           'close_approach_date_full': '1983-Dec-26 09:46',
#                           'epoch_date_close_approach': 441279960000,
#                           'miss_distance': {'astronomical': '0.4048337976',
#                                             'kilometers': '60562273.824971112',
#                                             'lunar': '157.4803472664',
#                                             'miles': '37631651.9519488656'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '72737.6743763478',
#                                                 'kilometers_per_second': '20.204909549',
#                                                 'miles_per_hour': '45196.3621701257'}},
#                          {'close_approach_date': '1984-10-24',
#                           'close_approach_date_full': '1984-Oct-24 02:43',
#                           'epoch_date_close_approach': 467433780000,
#                           'miss_distance': {'astronomical': '0.4350101183',
#                                             'kilometers': '65076587.126128021',
#                                             'lunar': '169.2189360187',
#                                             'miles': '40436716.1647318498'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30503.901010855',
#                                                 'kilometers_per_second': '8.4733058363',
#                                                 'miles_per_hour': '18953.9378253282'}},
#                          {'close_approach_date': '1985-07-02',
#                           'close_approach_date_full': '1985-Jul-02 21:01',
#                           'epoch_date_close_approach': 489186060000,
#                           'miss_distance': {'astronomical': '0.1010078571',
#                                             'kilometers': '15110560.275424377',
#                                             'lunar': '39.2920564119',
#                                             'miles': '9389266.7690633226'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '40996.6526999574',
#                                                 'kilometers_per_second': '11.3879590833',
#                                                 'miles_per_hour': '25473.7256734819'}},
#                          {'close_approach_date': '1990-12-18',
#                           'close_approach_date_full': '1990-Dec-18 07:58',
#                           'epoch_date_close_approach': 661507080000,
#                           'miss_distance': {'astronomical': '0.24398018',
#                                             'kilometers': '36498915.2502166',
#                                             'lunar': '94.90829002',
#                                             'miles': '22679374.27992508'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '23867.4354399315',
#                                                 'kilometers_per_second': '6.6298431778',
#                                                 'miles_per_hour': '14830.2962043285'}},
#                          {'close_approach_date': '1991-03-23',
#                           'close_approach_date_full': '1991-Mar-23 17:01',
#                           'epoch_date_close_approach': 669747660000,
#                           'miss_distance': {'astronomical': '0.2222875797',
#                                             'kilometers': '33253748.450575239',
#                                             'lunar': '86.4698685033',
#                                             'miles': '20662921.1348027382'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '24935.9201332206',
#                                                 'kilometers_per_second': '6.9266444815',
#                                                 'miles_per_hour': '15494.2110405559'}},
#                          {'close_approach_date': '1991-08-17',
#                           'close_approach_date_full': '1991-Aug-17 15:32',
#                           'epoch_date_close_approach': 682443120000,
#                           'miss_distance': {'astronomical': '0.3635085424',
#                                             'kilometers': '54380103.669844688',
#                                             'lunar': '141.4048229936',
#                                             'miles': '33790229.5466771744'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '22827.8700246788',
#                                                 'kilometers_per_second': '6.3410750069',
#                                                 'miles_per_hour': '14184.3506828345'}},
#                          {'close_approach_date': '1996-12-31',
#                           'close_approach_date_full': '1996-Dec-31 18:58',
#                           'epoch_date_close_approach': 852058680000,
#                           'miss_distance': {'astronomical': '0.2617179976',
#                                             'kilometers': '39152454.981625112',
#                                             'lunar': '101.8083010664',
#                                             'miles': '24328207.4116140656'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '57151.6886471803',
#                                                 'kilometers_per_second': '15.8754690687',
#                                                 'miles_per_hour': '35511.8367596882'}},
#                          {'close_approach_date': '1997-10-10',
#                           'close_approach_date_full': '1997-Oct-10 21:51',
#                           'epoch_date_close_approach': 876520260000,
#                           'miss_distance': {'astronomical': '0.4499914413',
#                                             'kilometers': '67317761.136710031',
#                                             'lunar': '175.0466706657',
#                                             'miles': '41829317.1191431878'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30320.8918251272',
#                                                 'kilometers_per_second': '8.4224699514',
#                                                 'miles_per_hour': '18840.2230343409'}},
#                          {'close_approach_date': '1998-07-11',
#                           'close_approach_date_full': '1998-Jul-11 12:30',
#                           'epoch_date_close_approach': 900160200000,
#                           'miss_distance': {'astronomical': '0.2461746981',
#                                             'kilometers': '36827210.483653047',
#                                             'lunar': '95.7619575609',
#                                             'miles': '22883367.4786921686'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '55503.3594274254',
#                                                 'kilometers_per_second': '15.417599841',
#                                                 'miles_per_hour': '34487.6290842244'}},
#                          {'close_approach_date': '2003-02-15',
#                           'close_approach_date_full': '2003-Feb-15 17:49',
#                           'epoch_date_close_approach': 1045331340000,
#                           'miss_distance': {'astronomical': '0.1392390213',
#                                             'kilometers': '20829861.007364631',
#                                             'lunar': '54.1639792857',
#                                             'miles': '12943075.4515926678'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '8396.5897094797',
#                                                 'kilometers_per_second': '2.3323860304',
#                                                 'miles_per_hour': '5217.3143114264'}},
#                          {'close_approach_date': '2003-11-28',
#                           'close_approach_date_full': '2003-Nov-28 15:41',
#                           'epoch_date_close_approach': 1070034060000,
#                           'miss_distance': {'astronomical': '0.3309481795',
#                                             'kilometers': '49509142.733577665',
#                                             'lunar': '128.7388418255',
#                                             'miles': '30763554.769655177'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '27266.6898860364',
#                                                 'kilometers_per_second': '7.5740805239',
#                                                 'miles_per_hour': '16942.4607239097'}},
#                          {'close_approach_date': '2004-05-03',
#                           'close_approach_date_full': '2004-May-03 17:57',
#                           'epoch_date_close_approach': 1083607020000,
#                           'miss_distance': {'astronomical': '0.1969885259',
#                                             'kilometers': '29469063.889079833',
#                                             'lunar': '76.6285365751',
#                                             'miles': '18311227.1977863754'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '26142.6418256606',
#                                                 'kilometers_per_second': '7.2618449516',
#                                                 'miles_per_hour': '16244.0209721723'}},
#                          {'close_approach_date': '2010-01-06',
#                           'close_approach_date_full': '2010-Jan-06 13:52',
#                           'epoch_date_close_approach': 1262785920000,
#                           'miss_distance': {'astronomical': '0.1258549454',
#                                             'kilometers': '18827631.760806298',
#                                             'lunar': '48.9575737606',
#                                             'miles': '11698947.8887429924'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '41890.9827139049',
#                                                 'kilometers_per_second': '11.6363840872',
#                                                 'miles_per_hour': '26029.4275646483'}},
#                          {'close_approach_date': '2010-09-27',
#                           'close_approach_date_full': '2010-Sep-27 21:53',
#                           'epoch_date_close_approach': 1285624380000,
#                           'miss_distance': {'astronomical': '0.4475362935',
#                                             'kilometers': '66950476.255294845',
#                                             'lunar': '174.0916181715',
#                                             'miles': '41601096.876545061'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '29355.5768682083',
#                                                 'kilometers_per_second': '8.1543269078',
#                                                 'miles_per_hour': '18240.4138601376'}},
#                          {'close_approach_date': '2011-07-18',
#                           'close_approach_date_full': '2011-Jul-18 23:20',
#                           'epoch_date_close_approach': 1311031200000,
#                           'miss_distance': {'astronomical': '0.3838981073',
#                                             'kilometers': '57430339.149111451',
#                                             'lunar': '149.3363637397',
#                                             'miles': '35685557.9859459838'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '69611.387351647',
#                                                 'kilometers_per_second': '19.3364964866',
#                                                 'miles_per_hour': '43253.8089908053'}},
#                          {'close_approach_date': '2016-11-14',
#                           'close_approach_date_full': '2016-Nov-14 21:24',
#                           'epoch_date_close_approach': 1479158640000,
#                           'miss_distance': {'astronomical': '0.3797959436',
#                                             'kilometers': '56816664.197200132',
#                                             'lunar': '147.7406220604',
#                                             'miles': '35304238.0528685416'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '28993.2555979845',
#                                                 'kilometers_per_second': '8.0536821106',
#                                                 'miles_per_hour': '18015.2815130921'}},
#                          {'close_approach_date': '2017-06-07',
#                           'close_approach_date_full': '2017-Jun-07 19:17',
#                           'epoch_date_close_approach': 1496863020000,
#                           'miss_distance': {'astronomical': '0.1216010655',
#                                             'kilometers': '18191260.388530485',
#                                             'lunar': '47.3028144795',
#                                             'miles': '11303525.054011293'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '24399.5368288651',
#                                                 'kilometers_per_second': '6.7776491191',
#                                                 'miles_per_hour': '15160.9233145801'}},
#                          {'close_approach_date': '2018-06-28',
#                           'close_approach_date_full': '2018-Jun-28 17:53',
#                           'epoch_date_close_approach': 1530208380000,
#                           'miss_distance': {'astronomical': '0.1299706277',
#                                             'kilometers': '19443329.066482999',
#                                             'lunar': '50.5585741753',
#                                             'miles': '12081524.4541794262'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '8131.6810966328',
#                                                 'kilometers_per_second': '2.2588003046',
#                                                 'miles_per_hour': '5052.710401405'}},
#                          {'close_approach_date': '2023-01-09',
#                           'close_approach_date_full': '2023-Jan-09 13:59',
#                           'epoch_date_close_approach': 1673272740000,
#                           'miss_distance': {'astronomical': '0.0725378623',
#                                             'kilometers': '10851509.694433301',
#                                             'lunar': '28.2172284347',
#                                             'miles': '6742815.4556135138'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '32387.3479203461',
#                                                 'kilometers_per_second': '8.9964855334',
#                                                 'miles_per_hour': '20124.2384897284'}},
#                          {'close_approach_date': '2023-09-19',
#                           'close_approach_date_full': '2023-Sep-19 00:06',
#                           'epoch_date_close_approach': 1695081960000,
#                           'miss_distance': {'astronomical': '0.4367404362',
#                                             'kilometers': '65335438.998390894',
#                                             'lunar': '169.8920296818',
#                                             'miles': '40597559.2597625772'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '28339.6744126064',
#                                                 'kilometers_per_second': '7.8721317813',
#                                                 'miles_per_hour': '17609.1715815442'}},
#                          {'close_approach_date': '2024-07-22',
#                           'close_approach_date_full': '2024-Jul-22 14:57',
#                           'epoch_date_close_approach': 1721660220000,
#                           'miss_distance': {'astronomical': '0.4698904161',
#                                             'kilometers': '70294605.381973707',
#                                             'lunar': '182.7873718629',
#                                             'miles': '43679042.3602508766'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '78572.9365774927',
#                                                 'kilometers_per_second': '21.825815716',
#                                                 'miles_per_hour': '48822.1671750537'}},
#                          {'close_approach_date': '2029-11-08',
#                           'close_approach_date_full': '2029-Nov-08 09:25',
#                           'epoch_date_close_approach': 1888824300000,
#                           'miss_distance': {'astronomical': '0.4003634556',
#                                             'kilometers': '59893520.183599572',
#                                             'lunar': '155.7413842284',
#                                             'miles': '37216107.7082432136'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '29746.2137327819',
#                                                 'kilometers_per_second': '8.262837148',
#                                                 'miles_per_hour': '18483.1404163499'}},
#                          {'close_approach_date': '2030-06-20',
#                           'close_approach_date_full': '2030-Jun-20 05:07',
#                           'epoch_date_close_approach': 1908162420000,
#                           'miss_distance': {'astronomical': '0.0651514024',
#                                             'kilometers': '9746511.026552888',
#                                             'lunar': '25.3438955336',
#                                             'miles': '6056201.1221223344'},
#                           'orbiting_body': 'Earth',
# ...
#                                             'kilometers': '17204360.308022233',
#                                             'lunar': '44.7365738551',
#                                             'miles': '10690293.7798954954'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '42267.5545201776',
#                                                 'kilometers_per_second': '11.7409873667',
#                                                 'miles_per_hour': '26263.414640607'}},
#                          {'close_approach_date': '2167-01-03',
#                           'close_approach_date_full': '2167-Jan-03 22:53',
#                           'epoch_date_close_approach': 6216994380000,
#                           'miss_distance': {'astronomical': '0.1705787384',
#                                             'kilometers': '25518215.931927208',
#                                             'lunar': '66.3551292376',
#                                             'miles': '15856284.1144351504'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '22184.4877081659',
#                                                 'kilometers_per_second': '6.1623576967',
#                                                 'miles_per_hour': '13784.5779317767'}},
#                          {'close_approach_date': '2167-09-04',
#                           'close_approach_date_full': '2167-Sep-04 01:03',
#                           'epoch_date_close_approach': 6237997380000,
#                           'miss_distance': {'astronomical': '0.4019430638',
#                                             'kilometers': '60129826.205754106',
#                                             'lunar': '156.3558518182',
#                                             'miles': '37362941.4616384228'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '25646.0511885948',
#                                                 'kilometers_per_second': '7.1239031079',
#                                                 'miles_per_hour': '15935.4588621577'}},
#                          {'close_approach_date': '2172-12-24',
#                           'close_approach_date_full': '2172-Dec-24 10:53',
#                           'epoch_date_close_approach': 6405475980000,
#                           'miss_distance': {'astronomical': '0.4677827683',
#                                             'kilometers': '69979305.760383521',
#                                             'lunar': '181.9674968687',
#                                             'miles': '43483124.2602377498'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '79561.3297661021',
#                                                 'kilometers_per_second': '22.1003693795',
#                                                 'miles_per_hour': '49436.3162649427'}},
#                          {'close_approach_date': '2173-11-02',
#                           'close_approach_date_full': '2173-Nov-02 13:07',
#                           'epoch_date_close_approach': 6432527220000,
#                           'miss_distance': {'astronomical': '0.4173356106',
#                                             'kilometers': '62432518.420909422',
#                                             'lunar': '162.3435525234',
#                                             'miles': '38793768.0558251436'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30265.1818954356',
#                                                 'kilometers_per_second': '8.406994971',
#                                                 'miles_per_hour': '18805.6070505278'}},
#                          {'close_approach_date': '2174-06-28',
#                           'close_approach_date_full': '2174-Jun-28 18:01',
#                           'epoch_date_close_approach': 6453108060000,
#                           'miss_distance': {'astronomical': '0.0341016961',
#                                             'kilometers': '5101541.099947307',
#                                             'lunar': '13.2655597829',
#                                             'miles': '3169950.6469425566'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '32787.1741704414',
#                                                 'kilometers_per_second': '9.1075483807',
#                                                 'miles_per_hour': '20372.674972739'}},
#                          {'close_approach_date': '2179-01-22',
#                           'close_approach_date_full': '2179-Jan-22 18:07',
#                           'epoch_date_close_approach': 6597310020000,
#                           'miss_distance': {'astronomical': '0.1265836655',
#                                             'kilometers': '18936646.735592485',
#                                             'lunar': '49.2410458795',
#                                             'miles': '11766686.652986893'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '8504.843533183',
#                                                 'kilometers_per_second': '2.362456537',
#                                                 'miles_per_hour': '5284.5790276047'}},
#                          {'close_approach_date': '2180-01-11',
#                           'close_approach_date_full': '2180-Jan-11 07:19',
#                           'epoch_date_close_approach': 6627856740000,
#                           'miss_distance': {'astronomical': '0.1105472035',
#                                             'kilometers': '16537626.178056545',
#                                             'lunar': '43.0028621615',
#                                             'miles': '10276004.402388521'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '25028.561975173',
#                                                 'kilometers_per_second': '6.9523783264',
#                                                 'miles_per_hour': '15551.7750784068'}},
#                          {'close_approach_date': '2180-09-11',
#                           'close_approach_date_full': '2180-Sep-11 17:17',
#                           'epoch_date_close_approach': 6648974220000,
#                           'miss_distance': {'astronomical': '0.4212765226',
#                                             'kilometers': '63022070.461966862',
#                                             'lunar': '163.8765672914',
#                                             'miles': '39160098.7071602156'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '27151.403851527',
#                                                 'kilometers_per_second': '7.5420566254',
#                                                 'miles_per_hour': '16870.8264654113'}},
#                          {'close_approach_date': '2186-11-06',
#                           'close_approach_date_full': '2186-Nov-06 01:19',
#                           'epoch_date_close_approach': 6843057540000,
#                           'miss_distance': {'astronomical': '0.410515109',
#                                             'kilometers': '61412185.90921783',
#                                             'lunar': '159.690377401',
#                                             'miles': '38159762.832272854'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30109.50434028',
#                                                 'kilometers_per_second': '8.3637512056',
#                                                 'miles_per_hour': '18708.8750718812'}},
#                          {'close_approach_date': '2187-06-26',
#                           'close_approach_date_full': '2187-Jun-26 02:36',
#                           'epoch_date_close_approach': 6863106960000,
#                           'miss_distance': {'astronomical': '0.0402655777',
#                                             'kilometers': '6023644.658239499',
#                                             'lunar': '15.6633097253',
#                                             'miles': '3742919.2291591262'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30165.3515572662',
#                                                 'kilometers_per_second': '8.3792643215',
#                                                 'miles_per_hour': '18743.5763606802'}},
#                          {'close_approach_date': '2193-01-10',
#                           'close_approach_date_full': '2193-Jan-10 21:55',
#                           'epoch_date_close_approach': 7038136500000,
#                           'miss_distance': {'astronomical': '0.0817953985',
#                                             'kilometers': '12236417.391401195',
#                                             'lunar': '31.8184100165',
#                                             'miles': '7603357.194658691'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '28592.3722845231',
#                                                 'kilometers_per_second': '7.9423256346',
#                                                 'miles_per_hour': '17766.1882120138'}},
#                          {'close_approach_date': '2193-09-16',
#                           'close_approach_date_full': '2193-Sep-16 23:43',
#                           'epoch_date_close_approach': 7059656580000,
#                           'miss_distance': {'astronomical': '0.4305068092',
#                                             'kilometers': '64402901.676816404',
#                                             'lunar': '167.4671487788',
#                                             'miles': '40018107.4376742152'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '27939.8754769636',
#                                                 'kilometers_per_second': '7.7610765214',
#                                                 'miles_per_hour': '17360.7520706722'}},
#                          {'close_approach_date': '2194-07-26',
#                           'close_approach_date_full': '2194-Jul-26 01:00',
#                           'epoch_date_close_approach': 7086618000000,
#                           'miss_distance': {'astronomical': '0.4918054485',
#                                             'kilometers': '73573047.549994695',
#                                             'lunar': '191.3123194665',
#                                             'miles': '45716171.860508991'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '81013.8668652799',
#                                                 'kilometers_per_second': '22.503851907',
#                                                 'miles_per_hour': '50338.866330818'}},
#                          {'close_approach_date': '2199-11-12',
#                           'close_approach_date_full': '2199-Nov-12 07:50',
#                           'epoch_date_close_approach': 7253826600000,
#                           'miss_distance': {'astronomical': '0.3929919143',
#                                             'kilometers': '58790753.306502541',
#                                             'lunar': '152.8738546627',
#                                             'miles': '36530880.1452394258'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '29592.7308984083',
#                                                 'kilometers_per_second': '8.2202030273',
#                                                 'miles_per_hour': '18387.7721518471'}},
#                          {'close_approach_date': '2200-06-17',
#                           'close_approach_date_full': '2200-Jun-17 14:15',
#                           'epoch_date_close_approach': 7272598500000,
#                           'miss_distance': {'astronomical': '0.0918865064',
#                                             'kilometers': '13746025.639181368',
#                                             'lunar': '35.7438509896',
#                                             'miles': '8541384.2629361584'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '25706.39487551',
#                                                 'kilometers_per_second': '7.1406652432',
#                                                 'miles_per_hour': '15972.9540825079'}}],
#  'designation': '226554',
#  'estimated_diameter': {'feet': {'estimated_diameter_max': 2322.8706681664,
#                                  'estimated_diameter_min': 1038.8193433921},
#                         'kilometers': {'estimated_diameter_max': 0.708010957,
#                                        'estimated_diameter_min': 0.3166321257},
#                         'meters': {'estimated_diameter_max': 708.0109570008,
#                                    'estimated_diameter_min': 316.6321257337},
#                         'miles': {'estimated_diameter_max': 0.4399374764,
#                                   'estimated_diameter_min': 0.1967460206}},
#  'id': '2226554',
#  'is_potentially_hazardous_asteroid': True,
#  'is_sentry_object': False,
#  'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2226554?api_key=DEMO_KEY'},
#  'name': '226554 (2003 WR21)',
#  'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2226554',
#  'neo_reference_id': '2226554',
#  'orbital_data': {'aphelion_distance': '1.410767859530534',
#                   'ascending_node_longitude': '85.76346778294662',
#                   'data_arc_in_days': 12071,
#                   'eccentricity': '.2615051933852866',
#                   'epoch_osculation': '2460600.5',
#                   'equinox': 'J2000',
#                   'first_observation_date': '1990-10-24',
#                   'inclination': '9.265537591243049',
#                   'jupiter_tisserand_invariant': '5.536',
#                   'last_observation_date': '2023-11-11',
#                   'mean_anomaly': '123.0853200281197',
#                   'mean_motion': '.8334015477971903',
#                   'minimum_orbit_intersection': '.0294529',
#                   'observations_used': 545,
#                   'orbit_class': {'orbit_class_description': 'Near-Earth '
#                                                              'asteroid orbits '
#                                                              'which cross the '
#                                                              'Earth’s orbit '
#                                                              'similar to that '
#                                                              'of 1862 Apollo',
#                                   'orbit_class_range': 'a (semi-major axis) > '
#                                                        '1.0 AU; q (perihelion) '
#                                                        '< 1.017 AU',
#                                   'orbit_class_type': 'APO'},
#                   'orbit_determination_date': '2024-01-18 05:26:44',
#                   'orbit_id': '121',
#                   'orbit_uncertainty': '0',
#                   'orbital_period': '431.9646405163704',
#                   'perihelion_argument': '108.1106483639542',
#                   'perihelion_distance': '.8258743151159244',
#                   'perihelion_time': '2460452.809705503363',
#                   'semi_major_axis': '1.118321087323229'}}

# %% [markdown]
# ## Exercise 1
#
# In the code cell below, **re-write the accumulator loop** that creates the list of hazards as a [list comprehension](https://realpython.com/lessons/list-comprehensions-overview/) that implements a ["filter"](https://youtu.be/hUes6y2b--0)
# Notice how this provides a concise way to "filter" items of interest from a larger data set.

# %%
# Ex. 1 your code here

# %% [markdown]
# ## Exercise 2
#
# In the code cell below, write a python function that takes a list of "close approach data" as a parameter,
# and returns a 2-tuple with the (date, miss km) of the closest approach to Earth in the list (where "miss km" is the miss distance in km).
#
# Hints:
# * notice the input is a list of dictionaries.  Each dictionary has a 'close_approach_date", "orbiting_body", and 'miss_distance' field.
# * we are only interested in the closest approach to "Earth"
# * use a loop if that is easier to understand - we will look at more compact algorithms to solve this problem in class.
#
# Add at least one unit test to check your work - note the test data only needs dictionaries with the fields your function actually uses.

# %%
# Ex. 2 your code here

# %% [markdown]
# ## Challenge - Take your skills to the next level...
# ## Exercise 3
#
# In the code cell below, write a complete program that:
#  1. fetches the list of NEO's for this week.
#  2. for each NEO, fetch it's complete orbital data and determine its closest approach to Earth
#  3. identify which NEO from this week's data makes the closet approach to earth
#  4. print a nice message with information about the NEO, which it will approach the Earth, and how close it will come.
#
# Hints:
# * you'll need the start and end date - end date is today, see if you can use a [`timedelta`](https://docs.python.org/3/library/datetime.html#timedelta-objects) object to ge the start date (you can do basic "date math" with `timedelta` and `date` objects!)
# * you may need to modify the function we wrote in Ex. 2 to return a triple with the NEO's id included;
# * lots of opportunity here for more practice with list comprehensions

# %%
# Ex. 3 (challenge) your code here
