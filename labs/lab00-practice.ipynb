# %% [markdown]
# <a href="https://colab.research.google.com/github/Hamilton-at-CapU/comp215/blob/main/labs/lab00-practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# COMP 215 - LAB 0
# ----------------
# #### Name:
# #### Date:
#
# This lab exercise is to introduce you to the computing tools we will be using for the course, including:
#   - Jupyter Notebooks
#   - Google Colaboratory
#   - GitHub

# %%
# add some code here
print('some code')
